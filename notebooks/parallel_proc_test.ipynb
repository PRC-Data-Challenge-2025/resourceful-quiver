# %%
from resqu import data
from resqu.data import FlightSet
import joblib
import pickle
from tqdm.contrib.concurrent import process_map
from concurrent.futures import ProcessPoolExecutor, as_completed
from fastmeteo.source import ArcoEra5
import pandas as pd

# %%
model_path = data.model_dir / "lgbm_mass_estim_24_feat.pkl"

def load_model(model_path):
    model = joblib.load(model_path)

    return model

model = load_model(model_path)

def pass_model(model):
    print('passed in\n')
    model = pickle.loads(model)
    # return load_model(model)
    # return model

with ProcessPoolExecutor(max_workers=8) as exe:
    future = exe.submit(pass_model, model_path) # this doesn't work, function hangs
    future.result()
# Out:
# Process ForkProcess-38:
# Process ForkProcess-35:
# Process ForkProcess-34:
# Process ForkProcess-36:
# Process ForkProcess-39:
# Process ForkProcess-37:
# Process ForkProcess-40:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# ...

# %%
pickle.loads(pickle.dumps(model))
# Out:
# LGBMRegressor(force_col_wise=True, learning_rate=0.08, n_estimators=800,
#               n_jobs=1, num_leaves=215)

# %%
result = process_map(pass_model, [pickle.dumps(model)] * 10, max_workers=8)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
result

# %%
local_store = "/mnt/sda1/meteo/era5-zarr"
grid = ArcoEra5(local_store=local_store)


def interpolate(meteo_grid):
    df = pd.DataFrame(
        {
            "timestamp": ["2025-08-01T01:10:00", "2025-08-01T01:10:00"],
            "latitude": [40.3, 42.5],
            "longitude": [4.2, 6.6],
            "altitude": [25000, 30000],
        }
    )
    return meteo_grid.interpolate(df)
